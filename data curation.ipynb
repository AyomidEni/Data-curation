# %%
#Importing
import  requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Fetch the financial results page
r = requests.get('https://investors.coca-colacompany.com/financial-information/financial-results')
soup = bs(r.text)
columns = soup.find_all(class_='link', title = 'XBRL Spreadsheet')
columns
# Out:
# [<a class="link" href="https://content.equisolve.net/sec/0000021344-24-000019/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://content.equisolve.net/sec/0000021344-24-000009/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://content.equisolve.net/sec/0000021344-23-000060/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://content.equisolve.net/sec/0000021344-23-000048/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000024/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000011/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000042/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000034/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000016/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000009/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000030/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000024/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000014/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000008/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000046/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000041/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000014/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000006/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000042/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000034/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000028/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000014/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000042/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000032/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000023/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000008/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000032/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000026/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000019/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000009/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000076/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000065/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000059/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000050/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000041/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000031/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000011/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000005/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000036/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000029/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000016/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000008/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000050/Financial_Report.xlsx" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000039/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000017/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000007/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-12-000051/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-12-000037/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-12-000023/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-12-000007/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-11-000011/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>,
#  <a class="link" href="https://s3.amazonaws.com/content.stockpr.com/sec/0001047469-11-006790/Financial_Report.xls" target="_blank" title="XBRL Spreadsheet"><span class="eqicon-PDF"></span> XLS</a>]

# %%
links = [column.get('href') for column in columns[2: -9]]
links
# Out:
# ['https://content.equisolve.net/sec/0000021344-23-000060/Financial_Report.xlsx',
#  'https://content.equisolve.net/sec/0000021344-23-000048/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000024/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000011/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000042/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000034/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000016/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000009/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000030/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000024/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000014/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000008/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000046/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000041/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000014/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000006/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000042/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000034/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000028/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000014/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000042/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000032/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000023/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000008/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000032/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000026/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000019/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000009/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000076/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000065/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000059/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000050/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000041/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000031/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000011/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000005/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000036/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000029/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000016/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000008/Financial_Report.xlsx',
#  'https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000050/Financial_Report.xlsx']

# %%
def downloads(download_link):
    try:
        df = pd.read_excel(download_link, engine='openpyxl', sheet_name=2)  # Read sheet 2
        
        return df
    
    except Exception as e:
        print(f"Error downloading/processing link: {download_link}. Error: {e}")
        
        return None  # Handle download errors gracefully

# %%
datas = []

for link in links:
    print(f'Downloading link --> {link}')
    df = downloads(link)
    if df is not None:  # Skip dataframes with download/processing errors
        datas.append(df)
# Out:
# Downloading link --> https://content.equisolve.net/sec/0000021344-23-000060/Financial_Report.xlsx
# Downloading link --> https://content.equisolve.net/sec/0000021344-23-000048/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000024/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-23-000011/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000042/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000034/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000016/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-22-000009/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000030/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000024/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000014/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-21-000008/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000046/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000041/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000014/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-20-000006/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000042/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000034/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000028/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-19-000014/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000042/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000032/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000023/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-18-000008/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000032/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000026/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000019/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-17-000009/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000076/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000065/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000059/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-16-000050/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000041/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000031/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000011/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-15-000005/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000036/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000029/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000016/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-14-000008/Financial_Report.xlsx
# Downloading link --> https://s3.amazonaws.com/content.stockpr.com/sec/0000021344-13-000050/Financial_Report.xlsx

# %%
def save_dataframe(df, filename):
    try:
        df.to_csv(filename, index=False)  # Save as CSV, without index
        print(f"Successfully saved dataframe to: {filename}")
    except Exception as e:
        print(f"Error saving dataframe: {e}")
        
# Check if any dataframes failed to download/process
if not all(df is not None for df in datas):
    print("Warning: Some dataframes may have download/processing errors.")

# Create a directory to save dataframes
data_dir = "downloaded_dataframes" 
os.makedirs(data_dir, exist_ok=True)  # Create directory if it doesn't exist

years_quarter = []
for y in ('2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013'):
    for q in ('_Q4', '_Q3', '_Q2', '_Q1'):
        year = y + q
         # Stop appending if reaching 2013 Q4
        if year == "2013_Q4":
            years_quarter.append(year)
            break  # Exit the inner loop after appending 2013 Q4
        else:
            years_quarter.append(year)
            
        
# Save individual dataframes with descriptive filenames
for i, (df, year_quarter) in enumerate(zip(datas, years_quarter)):
    if df is not None:
        filename = f"Financial_Report_{year_quarter}.csv"
        # Save the DataFrame
        save_dataframe(df, os.path.join(data_dir, filename))
# Out:
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2023_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2023_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2023_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2023_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2022_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2022_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2022_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2022_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2021_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2021_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2021_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2021_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2020_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2020_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2020_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2020_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2019_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2019_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2019_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2019_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2018_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2018_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2018_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2018_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2017_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2017_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2017_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2017_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2016_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2016_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2016_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2016_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2015_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2015_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2015_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2015_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2014_Q4.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2014_Q3.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2014_Q2.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2014_Q1.csv
# Successfully saved dataframe to: downloaded_dataframes\Financial_Report_2013_Q4.csv

# %%
# Define a base path for downloaded dataframes (modify as needed)
data_dir = "downloaded_dataframes"

# List of filenames (modify based on your actual file naming convention)
filenames = [f"Financial_Report_{i}.csv"  for i in years_quarter]

# Dictionary to store DataFrames with names (modify naming convention)
dataframes_dict = {}  # Key: dataframe name, Value: DataFrame object

for filename in filenames:
    # Extract a base name from the filename (modify the logic if needed)
    dataframe_name = os.path.splitext(filename)[0]  # Get filename without extension

    # Construct the full path to the CSV file
    file_path = os.path.join(data_dir, filename)

    # Check if the file exists before reading
    if os.path.exists(file_path):
        try:
            df = pd.read_csv(file_path, index_col= False)  # Read CSV, set first column as index
            df = df.T.reset_index()
             # **Handle duplicates and set headers within the loop:**
            df.drop_duplicates(inplace=True)  # Remove duplicate rows
            df.columns = df.iloc[0]  # Set first row as headers
            df = df.iloc[1:]  # Remove the former first row (now headers)
            dataframes_dict[dataframe_name] = df  # Store DataFrame with name
            print(f"Successfully read: {filename} (named {dataframe_name})")
        except FileNotFoundError:
            print(f"Error: File not found: {filename}")
        except pd.errors.ParserError as e:
            print(f"Error parsing CSV: {filename}. Error details: {e}")
    else:
        print(f"Warning: Skipping {filename} as it doesn't exist in the data directory.")
# Out:
# Successfully read: Financial_Report_2023_Q4.csv (named Financial_Report_2023_Q4)
# Successfully read: Financial_Report_2023_Q3.csv (named Financial_Report_2023_Q3)
# Successfully read: Financial_Report_2023_Q2.csv (named Financial_Report_2023_Q2)
# Successfully read: Financial_Report_2023_Q1.csv (named Financial_Report_2023_Q1)
# Successfully read: Financial_Report_2022_Q4.csv (named Financial_Report_2022_Q4)
# Successfully read: Financial_Report_2022_Q3.csv (named Financial_Report_2022_Q3)
# Successfully read: Financial_Report_2022_Q2.csv (named Financial_Report_2022_Q2)
# Successfully read: Financial_Report_2022_Q1.csv (named Financial_Report_2022_Q1)
# Successfully read: Financial_Report_2021_Q4.csv (named Financial_Report_2021_Q4)
# Successfully read: Financial_Report_2021_Q3.csv (named Financial_Report_2021_Q3)
# Successfully read: Financial_Report_2021_Q2.csv (named Financial_Report_2021_Q2)
# Successfully read: Financial_Report_2021_Q1.csv (named Financial_Report_2021_Q1)
# Successfully read: Financial_Report_2020_Q4.csv (named Financial_Report_2020_Q4)
# Successfully read: Financial_Report_2020_Q3.csv (named Financial_Report_2020_Q3)
# Successfully read: Financial_Report_2020_Q2.csv (named Financial_Report_2020_Q2)
# Successfully read: Financial_Report_2020_Q1.csv (named Financial_Report_2020_Q1)
# Successfully read: Financial_Report_2019_Q4.csv (named Financial_Report_2019_Q4)
# Successfully read: Financial_Report_2019_Q3.csv (named Financial_Report_2019_Q3)
# Successfully read: Financial_Report_2019_Q2.csv (named Financial_Report_2019_Q2)
# Successfully read: Financial_Report_2019_Q1.csv (named Financial_Report_2019_Q1)
# Successfully read: Financial_Report_2018_Q4.csv (named Financial_Report_2018_Q4)
# Successfully read: Financial_Report_2018_Q3.csv (named Financial_Report_2018_Q3)
# Successfully read: Financial_Report_2018_Q2.csv (named Financial_Report_2018_Q2)
# Successfully read: Financial_Report_2018_Q1.csv (named Financial_Report_2018_Q1)
# Successfully read: Financial_Report_2017_Q4.csv (named Financial_Report_2017_Q4)
# Successfully read: Financial_Report_2017_Q3.csv (named Financial_Report_2017_Q3)
# Successfully read: Financial_Report_2017_Q2.csv (named Financial_Report_2017_Q2)
# Successfully read: Financial_Report_2017_Q1.csv (named Financial_Report_2017_Q1)
# Successfully read: Financial_Report_2016_Q4.csv (named Financial_Report_2016_Q4)
# Successfully read: Financial_Report_2016_Q3.csv (named Financial_Report_2016_Q3)
# Successfully read: Financial_Report_2016_Q2.csv (named Financial_Report_2016_Q2)
# Successfully read: Financial_Report_2016_Q1.csv (named Financial_Report_2016_Q1)
# Successfully read: Financial_Report_2015_Q4.csv (named Financial_Report_2015_Q4)
# Successfully read: Financial_Report_2015_Q3.csv (named Financial_Report_2015_Q3)
# Successfully read: Financial_Report_2015_Q2.csv (named Financial_Report_2015_Q2)
# Successfully read: Financial_Report_2015_Q1.csv (named Financial_Report_2015_Q1)
# Successfully read: Financial_Report_2014_Q4.csv (named Financial_Report_2014_Q4)
# Successfully read: Financial_Report_2014_Q3.csv (named Financial_Report_2014_Q3)
# Successfully read: Financial_Report_2014_Q2.csv (named Financial_Report_2014_Q2)
# Successfully read: Financial_Report_2014_Q1.csv (named Financial_Report_2014_Q1)
# Successfully read: Financial_Report_2013_Q4.csv (named Financial_Report_2013_Q4)

# %%
for key, df in dataframes_dict.items():
    df = df.reset_index(drop = True)  # Reset index, dropping the old one
    dataframes_dict[key] = df


dataframes_dict['Financial_Report_2022_Q1']
# Out:
# 0 CONSOLIDATED STATEMENTS OF INCOME - USD ($) shares in Millions, $ in Millions  \
# 0                                    12 Months Ended
# 1                                         Unnamed: 2
# 2                                         Unnamed: 3
#
# 0            NaN Net Operating Revenues Cost of goods sold Gross Profit  \
# 0  Dec. 31, 2021                  38655              15357        23298
# 1  Dec. 31, 2020                  33014              13433        19581
# 2  Dec. 31, 2019                  37266              14619        22647
#
# 0 Selling, general and administrative expenses Other operating charges  \
# 0                                        12144                     846
# 1                                         9731                     853
# 2                                        12103                     458
#
# 0 Operating Income Interest income Interest expense  ...  \
# 0            10308             276             1597  ...
# 1             8997             370             1437  ...
# 2            10086             563              946  ...
#
# 0 Income Before Income Taxes Income taxes Consolidated Net Income  \
# 0                      12425         2621                    9804
# 1                       9749         1981                    7768
# 2                      10786         1801                    8985
#
# 0 Less: Net income (loss) attributable to noncontrolling interests  \
# 0                                                 33
# 1                                                 21
# 2                                                 65
#
# 0 Net Income Attributable to Shareowners of The Coca-Cola Company  \
# 0                                               9771
# 1                                               7747
# 2                                               8920
#
# 0 Basic Net Income Per Share1 Diluted Net Income Per Share1  \
# 0                        2.26                          2.25
# 1                         1.8                          1.79
# 2                        2.09                          2.07
#
# 0 Average Shares Outstanding — Basic Effect of dilutive securities  \
# 0                               4315                            25
# 1                               4295                            28
# 2                               4276                            38
#
# 0 Average Shares Outstanding — Diluted
# 0                                 4340
# 1                                 4323
# 2                                 4314
#
# [3 rows x 22 columns]
